# %%
type(1)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
type("bao tram")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# # Toán tử

# %% [markdown]
# ## Toán tử cộng

# %%
1+1
# Out:
# 2

# %% [markdown]
# ## Toán tử trừ

# %%
print(2-1)
# Out:
# 1

# %% [markdown]
# ## Toán tử nhân

# %%
print(5*3)
# Out:
# 15

# %% [markdown]
# ## Toán tử chia

# %%
print(7/7)
# Out:
# 1.0

# %% [markdown]
# ## Chia lấy dư

# %%
print(7%3)  # chia lấy phần dư
print(7//3)  # chia lấy phần nguyên
# Out:
# 1
# 2

# %% [markdown]
# ## Lũy thừa

# %%
print(6**2)
# Out:
# 36

# %%
# Special cases
print (1 + False)  # True=1, False=0

print("hello"+"world") # cộng string
print("hello"*3)    #nhân string
# Out:
# 1
# helloworld
# hellohellohello

# %% [markdown]
# ## Toán tử quan hệ

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# variable=biến
x=5 
y=4
z=9

# %%
print(x+y+(x<y)-1<=z)
# Out:
# True

# %%
print(x*y-z<=(z**2+40)**0.5)
# Out:
# True

# %% [markdown]
# ## Phép gán

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=1
# a=a+1
a += 1
print(a)
# Out:
# 2

# %% [markdown]
# ## Toán tử logic

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x=5
y=4
z=9

# %% [markdown]
# # Practice

# %% [markdown]
# ### EX1
# ![image.png](attachment:image.png)

# %%
diem_toan=6.5
diem_ly=6
diem_hoa=7
avg_score=(diem_toan+diem_ly+diem_hoa)/3
print(avg_score)
print(avg_score>=8)
print(6<=avg_score<8)
print(avg_score<6)
# Out:
# 6.5
# False
# True
# False

# %% [markdown]
# ### Ex2
# ![image.png](attachment:image.png)

# %%
v_km=33 

avg_per_minute=(33*1000)/60

print(avg_per_minute)

distance=(1+12/60)*33

print(distance)
# Out:
# 550.0
# 39.6

# %% [markdown]
# ### Ex3
# ![image.png](attachment:image.png)

# %%
cd=16
cr=10
cd_tang=cd+4
print(cd_tang)
dien_tich_cu=cd*cr
dien_tich_moi=cd_tang*cr
phan_tram_tang=((dien_tich_moi-dien_tich_cu)/dien_tich_cu)*100
print(phan_tram_tang)
# Out:
# 20
# 25.0

# %% [markdown]
# ### Ex4
# ![image.png](attachment:image.png)

# %%
v_xe_dap=12
v_xe_may=36
distance=48
v_difference=v_xe_may-v_xe_dap
t=distance/v_difference
print(t)
# Out:
# 2.0
